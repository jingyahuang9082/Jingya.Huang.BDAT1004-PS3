# %% [markdown]
# # # Question 1
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and
# materials.
#
# Occupations
#
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean age
# Step 8. For each occupation present the percentage of women and men

# %%
#Step 1 import libarary
import pandas as pd
#Step 2 and Step 3 import data and called it 'users'
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
#Step 4 the mean age per occupation
users.groupby('occupation').mean(['age'])
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %%
#Step 4 continus : the mean age per occupation
users.groupby('occupation').agg({'age':'mean'})
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
#Step 5 Discover the Male ratio per occupation and sort it from the most to the least
gender_count_by_occupation= users.groupby(['occupation', 'gender']).gender.count()
total_people = users.groupby('gender').gender.count()
print((gender_count_by_occupation /total_people).sort_values(ascending=False).xs('M',level=1))
# Out:
# occupation
# student          0.202985
# educator         0.102985
# other            0.102985
# engineer         0.097015
# programmer       0.089552
# administrator    0.064179
# executive        0.043284
# scientist        0.041791
# writer           0.038806
# technician       0.038806
# librarian        0.032836
# entertainment    0.023881
# marketing        0.023881
# artist           0.022388
# retired          0.019403
# lawyer           0.014925
# salesman         0.013433
# doctor           0.010448
# healthcare       0.007463
# none             0.007463
# homemaker        0.001493
# Name: gender, dtype: float64

# %%
#Step 6. For each occupation, calculate the minimum and maximum ages
users.groupby('occupation').agg({'age':['min','max']})
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %%
#Step 7 calculate the mean age by occupation and sex
users.groupby(['occupation','gender']).agg({'age':'mean'})
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %%
# Step 8 For each occupation present the percentage of women and men
total_People_By_Occupation = users.groupby('occupation').gender.count()
total_Gender_By_Occupation = users.groupby(['occupation', 'gender']).gender.count()
print(total_Gender_By_Occupation*100/total_People_By_Occupation)
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# # Question 2
#
# Euro Teams
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
# Step 1 import libarary
import pandas as pd

# Step 2 and Step 3 import data and called it 'euro12'
euro12=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 4 Select Goals column
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
# Step 5 the number of team participated in the Euro2012
Count_team=len(euro12.groupby('Team'))
print("The number of the Team  is :", Count_team)
# Out:
# The number of the Team  is : 16

# %%
euro12.shape
# Out:
# (16, 35)

# %%
# Step 6 the number of columns in the dataset
print("The number of columns  is :",len(euro12.columns))
# Out:
# The number of columns  is : 35

# %%
# Step 7  View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8 Sort the teams by Red Cards, then to Yellow Cards
sort_team = discipline.sort_values(by=['Red Cards', 'Yellow Cards'],ascending=False, inplace=False)
sort_team
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# Step 9  Calculate the mean Yellow Cards given per Team
euro12.groupby('Team').agg({'Yellow Cards': 'mean'})
# Out:
#                      Yellow Cards
# Team
# Croatia                         9
# Czech Republic                  7
# Denmark                         4
# England                         5
# France                          6
# Germany                         4
# Greece                          9
# Italy                          16
# Netherlands                     5
# Poland                          7
# Portugal                       12
# Republic of Ireland             6
# Russia                          6
# Spain                          11
# Sweden                          7
# Ukraine                         5

# %%
# Step 10. Filter teams that scored more than 6 goals
filter_teams = euro12[euro12["Goals"]>6]["Team"]
print("Teams that scored more than 6 goals are"," and ".join(list(filter_teams)))
# Out:
# Teams that scored more than 6 goals are Germany and Spain

# %%
#Step 11. Select the teams that start with G 
G=euro12[euro12["Team"].str.startswith('G')]["Team"]
print("Teams that start with letter G are"," and ".join(list(G)))
# Out:
# Teams that start with letter G are Germany and Greece

# %%
# Step 12 Select the first 7 columns
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
 # Step 13 Select all columns except the last 3
euro12.iloc[:,:-3]
# total number of columns is 35, except last 3 , the output should include 32 columns
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14 Present only the Shooting Accuracy from England, Italy and Russia
euro12_indexes = euro12.set_index('Team')
euro12_indexes
print(euro12_indexes.loc['England']["Shooting Accuracy"])
print(euro12_indexes.loc['Italy']["Shooting Accuracy"])
print(euro12_indexes.loc['Russia']["Shooting Accuracy"])
# Out:
# 50.0%
# 43.0%
# 22.5%

# %% [markdown]
# # Question 3
#
# Housing
#
# Step 1. Import the necessary libraries
# Step 2. Create 3 different Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
# Step 1 Import libraries
import pandas as pd
import numpy as np

# %%
# Step 2 Create 3 Series
#s1 random number from 1 to 4
s1 = pd.Series(np.random.randint(1,5, size=(100))) 
#s2 random number from 1 to 3
s2 = pd.Series(np.random.randint(1,4, size=(100))) 
#s3 random number from 10,000 to 30,000
s3 = pd.Series(np.random.randint(10000,30001, size=(100)))
print(s1)
print(s2)
print(s3)
# Out:
# 0     1
# 1     4
# 2     2
# 3     1
# 4     3
#      ..
# 95    1
# 96    4
# 97    3
# 98    3
# 99    1
# Length: 100, dtype: int32
# 0     3
# 1     3
# 2     3
# 3     2
# 4     3
#      ..
# 95    2
# 96    2
# 97    2
# 98    1
# 99    1
# Length: 100, dtype: int32
# 0     11693
# 1     26980
# 2     26990
# 3     28042
# 4     27702
#       ...
# 95    21969
# 96    24223
# 97    11028
# 98    24018
# 99    19823
# Length: 100, dtype: int32

# %%
# Step 3 Create a DataFrame by joinning the Series by column
df=pd.DataFrame({'s1':s1,'s2':s2,'s3':s3})
df
# Out:
#     s1  s2     s3
# 0    1   3  11693
# 1    4   3  26980
# 2    2   3  26990
# 3    1   2  28042
# 4    3   3  27702
# ..  ..  ..    ...
# 95   1   2  21969
# 96   4   2  24223
# 97   3   2  11028
# 98   3   1  24018
# 99   1   1  19823
#
# [100 rows x 3 columns]

# %%
# Step 4 Change the name of the columns to bedrs, bathrs, price_sqr_meter
df = pd.DataFrame({'s1':s1,'s2':s2,'s3':s3})
df.rename(columns = {'s1':'bedrs', 's2':'bathrs', 's3':'price_sqr_meter'}, inplace = True)
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       3            11693
# 1       4       3            26980
# 2       2       3            26990
# 3       1       2            28042
# 4       3       3            27702
# ..    ...     ...              ...
# 95      1       2            21969
# 96      4       2            24223
# 97      3       2            11028
# 98      3       1            24018
# 99      1       1            19823
#
# [100 rows x 3 columns]

# %%
# Step 5 Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([s1,s2,s3])
bigcolumn
# Out:
# 0         2
# 1         3
# 2         4
# 3         3
# 4         4
#       ...
# 95    10972
# 96    28638
# 97    28004
# 98    24862
# 99    23940
# Length: 300, dtype: int32

# %%
# Step 6 Ops it seems it is going only until index 99. Is it true?

# %% [markdown]
# ##  Yes, it is going only until index 99. It is true

# %%
# Step 7 Reindex the DataFrame so it goes from 0 to 299
bigcolumn.index = pd.RangeIndex(start=0, stop=300)
bigcolumn
# Out:
# 0          2
# 1          3
# 2          4
# 3          3
# 4          4
#        ...
# 295    10972
# 296    28638
# 297    28004
# 298    24862
# 299    23940
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4
#
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.

# %%
# Step 1 import libraries  
import numpy as np
import pandas as pd
import datetime

#Step 2 and Step 3
data=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',sep="\s+",
                 parse_dates={'datetime':['Yr','Mo','Dy']})
data
# Out:
#        datetime    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %%
# Step 4 Year 2061? Do we really have data from this year? Create a function to fix it and apply it
def fix_century(x):
    year=x.year-100 if x.year > 1979 else x.year
    
    return datetime.date(year,x.month,x.day)

data['datetime']=data['datetime'].apply(fix_century)
data
# Out:
#         datetime    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
# Step 5.Set the right dates as the index.
data.set_index(["datetime"],inplace=True)
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# datetime
# ...

# %%
#Step 6. missing values there are in total.
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
# Step 7 non-missing values there are in total.
data.notna().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
# Step 8 Calculate the mean windspeeds of the windspeeds over all the locations and all the times
data.mean().mean()
# Out:
# 10.227982360836924

# %%
# Step 9 Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
loc_stats=pd.DataFrame()
loc_stats['min']=data.min(axis=0)
loc_stats['max']=data.max(axis=0)
loc_stats['mean']=data.mean(axis=0)
loc_stats['standardDeviations ']=data.std(axis=0)
loc_stats
# Out:
#       min    max       mean  standardDeviations
# RPT  0.67  35.80  12.362987             5.618413
# VAL  0.21  33.37  10.644314             5.267356
# ROS  1.50  33.84  11.660526             5.008450
# KIL  0.00  28.46   6.306468             3.605811
# SHA  0.13  37.54  10.455834             4.936125
# BIR  0.00  26.16   7.092254             3.968683
# DUB  0.00  30.37   9.797343             4.977555
# CLA  0.00  31.08   8.495053             4.499449
# MUL  0.00  25.88   8.493590             4.166872
# CLO  0.04  28.21   8.707332             4.503954
# BEL  0.13  42.38  13.121007             5.835037
# MAL  0.67  42.54  15.599079             6.699794

# %%
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
day_stats=pd.DataFrame()
day_stats['min']=data.min(axis=1)
day_stats['max']=data.max(axis=1)
day_stats['mean']=data.mean(axis=1)
day_stats['stdstandardDeviations']=data.std(axis=1)
day_stats
# Out:
#              min    max       mean  stdstandardDeviations
# datetime
# 1961-01-01  9.29  18.50  13.018182               2.808875
# 1961-01-02  6.50  17.54  11.336364               3.188994
# 1961-01-03  6.17  18.50  11.641818               3.681912
# 1961-01-04  1.79  11.75   6.619167               3.198126
# 1961-01-05  6.17  13.33  10.630000               2.445356
# ...          ...    ...        ...                    ...
# 1978-12-27  8.08  40.08  16.708333               7.868076
# 1978-12-28  5.00  41.46  15.150000               9.687857
# 1978-12-29  8.71  29.58  14.890000               5.756836
# 1978-12-30  9.13  28.79  15.367500               5.540437
# 1978-12-31  9.59  27.29  15.402500               5.702483
#
# [6574 rows x 4 columns]

# %%
# Step 11 Find the average windspeed in January for each location
data_index = data['date'].apply(lambda x:x.month)
january_average=data.query('month==1')
january_average.loc[:,'RPT':'MAL'].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
# Step 12. Downsample the record to a yearly frequency for each location.
data.asfreq('Y')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
# 1961-12-31   9.87   7.83   7.67   3.75   5.66   3.50  10.04   3.08   5.04
# 1962-12-31  22.67  16.88  28.67  14.12  19.75  17.08  27.79  25.21  19.83
# 1963-12-31  13.88  14.42  12.12   9.25  14.33  10.67  18.29  11.96  12.04
# 1964-12-31  16.33  19.25  13.37  10.08  17.04  12.54  19.83  13.79  12.67
# 1965-12-31  13.62  13.88  12.29   6.08  12.33   7.41   9.59  10.21   7.46
# 1966-12-31  13.00  11.46  10.13   6.34  11.87   7.50  13.50   8.46  11.00
# 1967-12-31  16.88  13.75  11.34   9.08  13.54   7.71  11.75  11.83  11.83
# 1968-12-31   9.13   2.13   7.38   2.50   4.04   0.50   6.83   2.54   3.54
# 1969-12-31  14.42  13.83  27.71   7.08  12.08  10.00  14.58  11.00  12.54
# 1970-12-31   8.38   0.37   9.59   2.62   1.75   0.08   4.83   2.13   2.54
# 1971-12-31  14.88  10.50  26.08   8.46  13.50  10.04  21.04  10.25  13.54
# ...

# %%
# Step 13 Downsample the record to a monthly frequency for each location.
data.asfreq('M')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
# 1961-01-31  24.21  19.55  16.71  11.96  14.42  10.46  14.88   8.21  10.50
# 1961-02-28  12.92  12.75    NaN   8.92  16.13  12.29  14.75  14.46  13.96
# 1961-03-31   8.96   8.04   9.13   8.50  10.75   9.54  11.92   9.59  11.25
# 1961-04-30  11.67  11.00   9.54   5.54   9.42   5.79   5.09   8.25   6.96
# 1961-05-31   7.00   9.79  12.25   4.83   8.25   5.37   6.58   9.29   6.58
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-08-31  11.54   5.54   7.41   4.67   7.62   6.17   8.87   5.25   7.83
# 1978-09-30  26.75  15.63  16.54  13.37  17.58  13.13  16.92  13.79  13.46
# 1978-10-31   8.58   4.29  10.79   4.29   4.08   2.71   4.63   1.04   3.67
# 1978-11-30  15.34   4.54  14.75   3.50   4.54   4.96   7.50   2.42   4.96
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL        date  month
# datetime
# ...

# %%
# Step 14 Downsample the record to a weekly frequency for each location.
data.asfreq('W')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 1961-01-15  12.04   9.67  11.75   2.37   7.38   3.13   2.50   6.83   4.75
# 1961-01-22   9.59   5.88   9.92   2.17   6.87   5.50   9.38   7.04   6.34
# 1961-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-03  21.21  21.34  17.75  11.58  16.75  14.46  17.46  15.29  15.79
# 1978-12-10  24.92  22.54  16.54  14.62  15.59  13.00  13.21  14.12  16.21
# 1978-12-17   9.87   3.21   8.04   2.21   3.04   0.54   2.46   1.46   1.29
# 1978-12-24   8.67   5.63  12.12   4.79   5.09   5.91  12.25   9.25  10.83
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL        date  month
# datetime
# ...

# %%
# Step 15 Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks
df = data[data.index < pd.to_datetime('1962-01-01')]
df.asfreq('W').mean()
df.asfreq('W').min()
df.asfreq('W').max()
df.asfreq('W').std()
# Out:
# RPT      5.316556
# VAL      4.751895
# ROS      4.694975
# KIL      3.732070
# SHA      4.786117
# BIR      3.916581
# DUB      4.648917
# CLA      4.074002
# MUL      4.173736
# CLO      4.125701
# BEL      5.885851
# MAL      5.732441
# month    3.538816
# dtype: float64

# %% [markdown]
# # Question 5
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column?
# Step 12. How many items were orderd in total?
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type
# Step 14. How much was the revenue for the period in the dataset?
# Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?

# %%
# Step 1 Import library
import pandas as pd
# Step 2 and 3 upload the dataset and called chipo
chipo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
# Step 4 display first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5 What is the number of observations in the dataset
# Step 6 What is the number of columns in the dataset?
chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# The number of observations is 4622
#
# The number of columns in the dataset is 5

# %%
# Step 7 Print the name of all the columns.
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step 8 How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Step 9 Which was the most-ordered item?
# Step 10 For the most-ordered item, how many items were ordered?
chipo[chipo.quantity==chipo.quantity.max()]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %% [markdown]
# ### The most-ordered item is Chips and Fresh Tomato Salsa
#
# ### 15 items are ordered For he most ordered item

# %%
# Step 11 What was the most ordered item in the choice_description column?
chipo.groupby('choice_description').agg({'quantity':'sum'}).sort_values(by='quantity', ascending=False).head(1)
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %% [markdown]
# [Diet Coke] is the most ordered item in the choice_description column

# %%
# Step 12 How many items were orderd in total?
chipo.quantity.sum()
# Out:
# 4972

# %%
#Step13
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)
print(chipo['item_price'].dtype)
# Out:
# float64

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x.replace('$', '')))
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %%
# Step 14 How much was the revenue for the period in the dataset?
chipo['item_price'].sum()
# Out:
# 34500.16

# %%
#Step 15 How many orders were made in the period?
chipo['order_id'].sum()
# Out:
# 4285772

# %%
# Step 16 What is the average revenue amount per order?
chipo.groupby('order_id').item_price.agg('mean').mean()
# Out:
# 7.841910975496643

# %%
# Step 17 How many different items are sold?
print(len(chipo.groupby('item_name').item_name.agg('count')))
# Out:
# 50

# %% [markdown]
# # Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt
MaDivo=pd.read_csv('C:\\Users\\jane\\Downloads\\us-marriages-divorces-1867-2014.csv')

#Create x,y data
MaDivo.plot(x='Year', y=['Marriages_per_1000', 'Divorces_per_1000'])
# set xAxis labels
plt.xlabel('Year')
# set yAxis labels
plt.ylabel('Marriages and Divorces per Capita')
# set title
plt.title('Marriages and Divorces dataset')

plt.show()

# %% [markdown]
# # Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Create data
Divorces_per_1000 = [0.7, 2.5,3.3]
Marriages_per_1000 = [9.3,11,8.2]
index = ['1900', '1950', '2000']
df = pd.DataFrame({'Divorces_per_1000': Divorces_per_1000,
                  'Marriages_per_1000': Marriages_per_1000}, index=index)
# declaring the figure
Bchart = df.plot.bar(figsize=[8,5])
#lable x,y,and title
Bchart.set_xlabel('Year')
Bchart.set_ylabel('marriage and divorces per capita')
Bchart.set_title("Marriages and Divorces Bar Chart")
# Out:
# Text(0.5, 1.0, 'Marriages and Divorces Bar Chart')

# %% [markdown]
# # Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt
kill_actor=pd.read_csv('C:\\Users\\jane\\Downloads\\actor_kill_counts.csv')
# Create x,y data
x='Actor'
y='Count'
kill_actor.plot.barh(x, y)
# set axis labels
plt.ylabel('Actor name')
plt.xlabel('kill number')
plt.title('Horizontal Count by Actor')

plt.show()

# %% [markdown]
# # Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.

# %%
import matplotlib.pyplot as plt
import pandas as pd

roman= pd.read_csv('C:\\Users\\jane\\Downloads\\roman-emperor-reigns.csv')
assassinated_death = roman[roman['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
emperor = assassinated_death["Emperor"]
cause_of_death = assassinated_death["Cause_of_Death"]
plt.pie(range(len(cause_of_death)), labels=emperor,autopct='%1.2f%%', startangle=40, radius=0.045 * 100,rotatelabels = 300)
fig = plt.figure(figsize=[15, 10])
plt.title("Roman Emperor Reigns")
plt.show()

# %% [markdown]
# # Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\jane\\Downloads\\arcade-revenue-vs-cs-doctorates.csv')
sns.set(style="whitegrid", color_codes=True)
sns.scatterplot(x='Computer Science Doctorates Awarded',y='Total Arcade Revenue ',hue='Year',data=df)
# Out:
# <AxesSubplot:xlabel='Computer Science Doctorates Awarded', ylabel='Total Arcade Revenue '>
